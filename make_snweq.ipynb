# %%
import cartopy.crs as ccrs
import numpy as np
import xarray as xr
import pyremo as pr
import cmaps
import glob
import datetime
from REMO2020_mod import modelclass, open_snowcci_swemon, open_mfdataset, domainclass, plotclass, remo_plotter_mon

# %%
from dask.distributed import Client, progress
import dask
dask.config.set({'temporary_directory': '/scratch/g/g300096/dask/tmp'})
client = Client()
client
# Out:
# /work/ch0636/g300096/Python/envs/kernelR2020/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44841 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:39313' processes=16 threads=256, memory=486.93 GiB>

# %%
# define the runs to be plotted
modelruns =[] # init

modelruns.append(modelclass("056524","REMO2015",False))
modelruns.append(modelclass("036030","REMO2020$_{27}$",True))
modelruns.append(modelclass("036032","REMO2020$_{49}$",True))
modelruns.append(modelclass("036039","REMO2020$_{49}$ iMOVE",True))

# %%
# give path, prefix and suffix (the main name for the plots)
figpath = './figures/'
prefix = 'SnowCCI_weq_mon_'
suffix = 'REMO2020_2749_main'

# %%
# REMO and EOBS datapath
rdata = './data_in/model_data/'
snCCidata = './data_in/SnowCCI/'

# %%
# define star year and end year
ystart=2001
yend=2010

# %%
# Define the order of seasons to be used (also when plotting)
months = ["January","February","March","April"]

# %%
# lake fraction cut-off limit
clake = 0.5

# %%
# Load the lake mask
lake_mask = xr.open_dataset(rdata+"FLake_input/flake_v3_glcc_defD10.0m_frac_EUR-11.nc")["FLFRA"]

# %%
# Target grid
trggrid = "EUR-11"

# %%
# get monthly SWE CCI data
dsSnowCCImon = open_snowcci_swemon(snCCidata,trggrid,ystart,yend)

# %%
yearlist = np.arange(ystart,yend+1)
for obj in modelruns:
    for year in yearlist:
        pattern = rdata+"remo_results_"+obj.userexp+"/"+str(year)+"/e"+obj.userexp+"m*.nc"
        obj.filenames += glob.glob(pattern)
    obj.filenames.sort()

# %%
# Set halo zone length (will be cutted out)
halo = 8

# %%
# calculate the T2m difference to EOBS
ii = 0 
for obj in modelruns:
    ds = open_mfdataset(obj.filenames, parallel=False, chunks='auto')
    REMOvar = pr.parse_dates(ds)
    # Merge data (get identical coordinates) and change units to [cm]
    data_all = xr.merge([REMOvar[["SN"]]*100.0, dsSnowCCImon.where(dsSnowCCImon >= 0.0,drop=False)*0.1, lake_mask.squeeze().rename("lake_mask")], compat="override", join="override")    
    lake_mask["rlon"] = data_all.rlon
    lake_mask["rlat"] = data_all.rlat
    if (ii == 0):
        data_abs = data_all.swe.where(data_all.lake_mask < clake, drop=False)
        for mon in months:
            mondata = data_abs.where(data_abs['time.month'] == datetime.datetime.strptime(mon, '%B').month,drop=True).mean(dim="time").expand_dims({"time": [mon]}).squeeze()
            if(mon == months[0]):
                data_absmon = mondata
            else:
                data_absmon = xr.concat([data_absmon,mondata],dim="time", coords="all", compat="override", join="override")
        # cut the halo
        data_absmon = data_absmon.isel(rlat=slice(halo+1,data_absmon.sizes["rlat"]-halo+1), rlon=slice(halo+1,data_absmon.sizes["rlon"]-halo+1)).compute()
    # remove lakes
    datadiff = (data_all.SN-data_all.swe).where(data_all.lake_mask < clake, drop=False)
    for mon in months:
        mondiffdata = datadiff.where(datadiff['time.month'] == datetime.datetime.strptime(mon, '%B').month,drop=True).mean(dim="time").expand_dims({"time": [mon]}).squeeze()
        if(mon == months[0]):
            obj.vardiff = mondiffdata
        else:
            obj.vardiff = xr.concat([obj.vardiff,mondiffdata],dim="time", coords="all", compat="override", join="override")
    # cut the halo
    obj.vardiff = obj.vardiff.isel(rlat=slice(halo+1,obj.vardiff.sizes["rlat"]-halo+1), rlon=slice(halo+1,obj.vardiff.sizes["rlon"]-halo+1)).compute()
    # not supported, set to zero
    obj.mask = np.zeros(len(months))
    # increase counter
    ii = ii + 1
    #t_stat
    if(obj.r2020file):
        pole = (ds.rotated_latitude_longitude.grid_north_pole_longitude,ds.rotated_latitude_longitude.grid_north_pole_latitude)
        rotated_pole = ccrs.RotatedPole(pole[0], pole[1])
        extent = ([ds.rlon.min(), ds.rlon.max(), ds.rlat.min(), ds.rlat.max()], rotated_pole)
# Out:
# /work/ch0636/g300096/Python/envs/kernelR2020/lib/python3.10/site-packages/distributed/client.py:3370: UserWarning: Sending large graph of size 19.38 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /work/ch0636/g300096/Python/envs/kernelR2020/lib/python3.10/site-packages/distributed/client.py:3370: UserWarning: Sending large graph of size 19.43 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /work/ch0636/g300096/Python/envs/kernelR2020/lib/python3.10/site-packages/distributed/client.py:3370: UserWarning: Sending large graph of size 19.46 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /work/ch0636/g300096/Python/envs/kernelR2020/lib/python3.10/site-packages/distributed/client.py:3370: UserWarning: Sending large graph of size 19.44 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /work/ch0636/g300096/Python/envs/kernelR2020/lib/python3.10/site-packages/distributed/client.py:3370: UserWarning: Sending large graph of size 19.46 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
# define the domains to be plotted
domaininfo =[] # init
domaininfo.append(domainclass("NEU",[2,54,45,73], hspace=0.3, ylocs=range(-90,90,5)))

# %%
# define plotclasses for absolute and difference (model) plots
absplotc = plotclass(label='SWE [cm]', lspace=np.linspace(0,1,18), vmin=0, vmax=18, linvert=False, cmapp=cmaps.WhiteBlue)
modplotc = plotclass(label='$\Delta$SWE [cm]', lspace=np.linspace(0,1,20), vmin=-5, vmax=5, linvert=False, cmapp=cmaps.BlueWhiteOrangeRed)

# %%
# Loop over domains
for dom in range(len(domaininfo)):
    # Create figure name
    figname=prefix+domaininfo[dom].name+'_'+suffix
    # Call plotter (we can use the eobs plotter directly)
    remo_plotter_mon(absplotc,modplotc,domaininfo[dom],modelruns,"SnowCCI",data_absmon,months,pole,False,figpath,figname)
